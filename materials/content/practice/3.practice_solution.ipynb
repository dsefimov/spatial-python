# %% [markdown]
# # Модуль 2 часть 2 [решение]

# %% [markdown]
# ## Задача 1
#
# **Описание**: Пользователь хочет сохранить список координат. Сначала пользователь вводит число координат, которые у него есть. Далее пользователь поочередно вводит координаты в формате 'x, y'. Выведите на печать список со всеми координатами.
#
# **Задание**: Исправьте нижеуказанный код, чтобы он выполнялся без ошибок
#
# **Пример данных для проверки**:
#
# ```
# Input: 3
# Input: 10, 10
# Input: 20, 20
# Input: 30, 30
# Output: [(10, 10), (20, 20), (30, 30)]
# ```

# %%
coords_number = input("Укажите количество координат:")
coords_number = int(coords_number)

coords = []
for _ in range(coords_number):
    user_input = input("Введите координату:")
    x, y = user_input.split(', ')
    x, y = float(x), float(y)
    coords.append((x, y))

print(coords)
# Out:
# Укажите количество координат:3
# Введите координату:10, 10
# Введите координату:20, 20
# Введите координату:30, 30
# [(10.0, 10.0), (20.0, 20.0), (30.0, 30.0)]

# %% [markdown]
# ## Задача 2
#
# **Описание**: Пользователь хочет получить список значений долготы от -180 до 180 с заданным шагом. Шаг пользователь вводит с клавиатуры. Выведите на печать требуемый список значений
#
# **Задание**: Самостоятельно напишите код, чтобы он соответствовал описанию
#
# **Пример данных для проверки**:
#
# ```
# Input: 60
# Output: [-180, -120, -60, 0, 60, 120, 180]
# ```
# ```
# Input: 100
# Output: [-180, -80, 20, 120]
# ```

# %%
step = int(input("Укажите шаг:"))

longs = []

for i in range(-180, 181, step):
    longs.append(i)

print(longs)
# Out:
# Укажите шаг:60
# [-180, -120, -60, 0, 60, 120, 180]

# %%
step = int(input("Укажите шаг:"))
longs = list(range(-180, 181, step))
print(longs)
# Out:
# Укажите шаг:100
# [-180, -80, 20, 120]

# %% [markdown]
# ## Задача 3
#
# **Описание**: Пользователь хочет сгенерировать сетку регулярных точек, расстояние между, которыми будет задано шагом. Сетка должна быть определена в границах -180:180 по долготе и -90:90 по широте. Шаг пользователь вводит с клавиатуры. Выведите на печать список всех точек регулярной сетки.
#
# **Задание**: Самостоятельно напишите код, чтобы он соответствовал описанию
#
# **Пример данных для проверки**:
#
# ```
# Input: 100
# Output: [(-180, -90), (-80, -90), (20, -90), (120, -90), (-180, 10), (-80, 10), (20, 10), (120, 10)]
# ```
# ```
# Input: 200
# Output: [(-180, -90), (20, -90)]
# ```

# %%
step = int(input("Укажите шаг:"))

points = []

for x in range(-180, 181, step):
    for y in range(-90, 91, step):
        points.append((x, y))

print(points)
# Out:
# Укажите шаг:100
# [(-180, -90), (-180, 10), (-80, -90), (-80, 10), (20, -90), (20, 10), (120, -90), (120, 10)]

# %% [markdown]
# ## Задача 4
#
# **Описание**: Пользователь одновременно отслеживает несколько GPS треков. Сначала пользователь указывает, какое количество измерений он получил. Далее пользователь вводит данные в формате '№трека, x, y'. Номера треков могут повторяться и идти не по порядку. На выходе нужно напечатать словарь, где в качестве ключей будут храниться номера треков, а в качестве значений будут списки соответсвующих им координат.
#
# **Задание**: Самостоятельно напишите код, чтобы он соответствовал описанию
#
# **Пример данных для проверки**:
#
# ```
# Input: 5
# Input: 1, 10, 10
# Input: 1, 20, 20
# Input: 2, 10, 10
# Input: 1, 30, 30
# Input: 2, 0, 0
# Output: {1: [(10, 10), (20, 20), (30, 30)], 2: [(10, 10), (0, 0)]}
# ```

# %%
measurements_number = input("Укажите количество измерений:")
measurements_number = int(measurements_number)

tracks = {}

for _ in range(measurements_number):
    user_input = input("Введите координату:")
    track, x, y = user_input.split(', ')
    x, y = float(x), float(y)
    tracks.setdefault(track, []).append((x, y))

print(tracks)
# Out:
# Укажите количество измерений:5
# Введите координату:1, 10, 10
# Введите координату:1, 20, 20
# Введите координату:2, 10, 10
# Введите координату:1, 30, 30
# Введите координату:2, 0, 0
# {'1': [(10.0, 10.0), (20.0, 20.0), (30.0, 30.0)], '2': [(10.0, 10.0), (0.0, 0.0)]}

# %% [markdown]
# ## Задача 5
#
# **Описание**: Пользователь одновременно отслеживает несколько GPS треков. Сначала пользователь указывает, какое количество измерений он получил. Далее пользователь вводит данные в формате '№трека, x, y'. Номера треков могут повторяться и идти не по порядку. На выходе нужно напечатать расстояния, которые прошел каждый трек.
#
# **Задание**: Самостоятельно напишите код, чтобы он соответствовал описанию
#
# **Пример данных для проверки**:
#
# ```
# Input: 5
# Input: 1, 10, 10
# Input: 1, 10, 30
# Input: 2, 0, 10
# Input: 1, 40, 30
# Input: 2, 0, 0
# Output:
# 1 50
# 2 10
# ```

# %%
measurements_number = input("Укажите количество измерений:")
measurements_number = int(measurements_number)

tracks = {}

for _ in range(measurements_number):
    user_input = input("Введите координату:")
    track, x, y = user_input.split(', ')
    x, y = float(x), float(y)
    tracks.setdefault(track, []).append((x, y))

for track, coordinates in tracks.items():
    distance = 0
    for i in range(len(coordinates) - 1):
        x1, y1 = coordinates[i]
        x2, y2 = coordinates[i+1]
        distance += ((x2-x1)**2 + (y2-y1)**2)**0.5
    print(track, distance)
# Out:
# Укажите количество измерений:5
# Введите координату:1, 10, 10
# Введите координату:1, 10, 30
# Введите координату:2, 0, 10
# Введите координату:1, 40, 30
# Введите координату:2, 0, 0
# 1 50.0
# 2 10.0

# %%
measurements_number = input("Укажите количество измерений:")
measurements_number = int(measurements_number)

tracks = {}
distances = {}

for _ in range(measurements_number):
    user_input = input("Введите координату:")
    track, x, y = user_input.split(', ')
    x, y = float(x), float(y)

    if not tracks.get(track):
        tracks[track] = [(x, y)]
        distances[track] = 0
        continue

    x2, y2 = tracks[track][-1]
    distance = ((x2-x)**2 + (y2-y)**2)**0.5
    distances[track] += distance

    tracks[track].append((x, y))

for track, distance in distances.items():
    print(track, distance)
# Out:
# Укажите количество измерений:5
# Введите координату:1, 10, 10
# Введите координату:1, 10, 30
# Введите координату:2, 0, 10
# Введите координату:1, 40, 30
# Введите координату:2, 0, 0
# 1 50.0
# 2 10.0

# %%
measurements_number = input("Укажите количество измерений:")
measurements_number = int(measurements_number)

tracks = {}
distances = {}

for _ in range(measurements_number):
    user_input = input("Введите координату:")
    track, x, y = user_input.split(', ')
    x, y = float(x), float(y)
    tracks.setdefault(track, []).append((x, y))

    x2, y2 = tracks.get(track, [(x, y)])[-1]
    distance = ((x2-x)**2 + (y2-y)**2)**0.5
    distances[track] = distances.setdefault(track, 0) + distance

for track, distance in distances.items():
    print(track, distance)
# Out:
# Укажите количество измерений:5
# Введите координату:1, 10, 10
# Введите координату:1, 10, 30
# Введите координату:2, 0, 10
# Введите координату:1, 40, 30
# Введите координату:2, 0, 0
# 1 50.0
# 2 10.0
